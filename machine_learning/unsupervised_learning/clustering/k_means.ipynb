# %% [markdown]
# <a href="https://colab.research.google.com/github/PsorTheDoctor/Sekcja-SI/blob/master/machine_learning/unsupervised_learning/clustering/k_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algorytm K-średnich
# Instalacja biblioteki scikit-learn:

# %%
# !pip install scikit-learn

# %% [markdown]
# Aktualizacja do najnowszej wersji:

# %%
# !pip install --upgrade scikit-learn

# %% [markdown]
# ### Import bibliotek

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Wygenerowanie danych

# %%
from sklearn.datasets import make_blobs

data = make_blobs(n_samples=1000, centers=None, cluster_std=1.0, center_box=(-4.0, 4.0), random_state=42)[0]
df = pd.DataFrame(data, columns=['x1', 'x2'])
df.head()
# Out:
#          x1        x2
# 0 -2.468563 -3.010949
# 1 -2.009756 -2.452751
# 2  2.414278  0.865273
# 3 -1.463040  2.755870
# 4 -1.263270  2.102571

# %%
px.scatter(df, x='x1', y='x2', width=950, height=500, title='Klasteryzacja - Algorytm K-średnich')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="342b72f0-5f57-47c1-8cc4-013893860483" class="plotly-graph-div" style="height:500px; width:950px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("342b72f0-5f57-47c1-8cc4-013893860483")) {
#                     Plotly.newPlot(
#                         '342b72f0-5f57-47c1-8cc4-013893860483',
# ...

# %% [markdown]
# ### Algorytm K-średnich

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
y_kmeans = kmeans.predict(data)
y_kmeans[:10]
# Out:
# array([0, 0, 1, 2, 2, 0, 1, 1, 1, 1], dtype=int32)

# %%
df['y_kmeans'] = y_kmeans
df.head()
# Out:
#          x1        x2  y_kmeans
# 0 -2.468563 -3.010949         0
# 1 -2.009756 -2.452751         0
# 2  2.414278  0.865273         1
# 3 -1.463040  2.755870         2
# 4 -1.263270  2.102571         2

# %% [markdown]
# ### Wizualizacja klastrów

# %%
px.scatter(df, x='x1', y='x2', color='y_kmeans', width=950, height=500, title='Algorytm K-średnich - 3 klastry')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f3e29f19-5a03-4864-8b3f-357662f14237" class="plotly-graph-div" style="height:500px; width:950px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f3e29f19-5a03-4864-8b3f-357662f14237")) {
#                     Plotly.newPlot(
#                         'f3e29f19-5a03-4864-8b3f-357662f14237',
# ...
