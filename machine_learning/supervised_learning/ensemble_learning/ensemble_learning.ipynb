# %% [markdown]
# <a href="https://colab.research.google.com/github/PsorTheDoctor/Sekcja-SI/blob/master/machine_learning/ensemble_learning/ensemble_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uczenie zespołowe - Las losowy

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Generowanie zestawu danych

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=300, centers=4,
                  random_state=0, cluster_std=1.0)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='viridis')

# %% [markdown]
# ### Drzewo decyzyjne

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=10)
clf.fit(X, y)

from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X, y, clf)

# %%
clf.score(X, y)
# Out:
# 1.0

# %% [markdown]
# ### Metody zespołowe
# #### Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

tree = DecisionTreeClassifier()
bag = BaggingClassifier(base_estimator=tree, n_estimators=100, max_samples=0.8)
bag.fit(X, y)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=None,
#                                                         max_features=None,
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         presort=False,
#                                                         random_state=None,
# ...

# %%
plot_decision_regions(X, y, bag)

# %%
bag.score(X, y)
# Out:
# 1.0

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# uczenie zespołowe dla 100 drzew decyzyjnych (n_estimators=100)
# predykcje są tworzone na podstawie losowania wśród tych modeli
forest = RandomForestClassifier(n_estimators=100)
forest.fit(X, y)
plot_decision_regions(X, y, forest)

# %%
forest.score(X, y)
# Out:
# 1.0
